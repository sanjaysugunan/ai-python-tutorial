# %%
with open("joke.txt","w") as f:
    f.write("Hi. I am mad \n")
    f.write("see you \n")
    f.write("soon... \n")

# %%
ls
# Out:
# joke.txt  Untitled.ipynb

# %%
with open("joke.txt", "r") as f:
    lines = f.readlines()
    print(lines)
# Out:
# ['Hi. I am mad \n', 'see you \n', 'soon... \n']

# %%
with open("joke.txt", "r") as f:
    for line in f:
        print(line)
# Out:
# Hi. I am mad
#
# see you
#
# soon...

# %%
with open("joke.txt", "r") as f:
    content = f.read()
    print(content)
# Out:
# Hi. I am mad
# see you
# soon...

# %%
# read the document
with open("meeting.txt","r",encoding="utf-8") as f:
    document = f.read()
print(document)
# Out:
# **Team Meeting Transcript**
#
# **Manager:** Good morning, everyone. Let's do a quick project update.
#
# **Alice:** The authentication module is complete and has been merged into the main branch.
#
# **Bob:** I fixed the payment API bug and started working on performance improvements.
#
# **Manager:** Great. Any blockers?
#
# **Alice:** None from my side.
#
# **Bob:** I'm waiting for the design team to finalize the dashboard assets.
#
# **Manager:** Understood. Please follow up with them today. Our goal is to finish all remaining tasks by Friday. Thanks, everyone.

# %%
from dotenv import load_dotenv
from google import genai

load_dotenv()
client = genai.Client()

# put it in the prompt and ask
prompt = f'''
Here is a meeting transcript:
{document}

Summarize it in 3 short bullet points.
'''

try:
    response = client.models.generate_content(
        model="gemini-3.5-flash",
        contents = prompt
        )
    summary = response.text
except Exception as e:
    return f"Sorry, something went wrong: {e}"

        
        
    
        response = client.models.generate_content(
        model="gemini-3.5-flash",
        contents = prompt
        )
        summary = response.text
    except Exception as e:
        return f"Sorry, something went wrong: {e}"
